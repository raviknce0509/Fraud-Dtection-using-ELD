# %%
# %pip install folium 
# %pip install openpyxl
import os
import numpy as np
import pandas as pd
import folium
# Out:
# Requirement already satisfied: folium in /usr/local/python/3.10.4/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /home/codespace/.local/lib/python3.10/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from folium) (1.24.2)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from folium) (2.28.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->folium) (3.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openpyxl in /usr/local/python/3.10.4/lib/python3.10/site-packages (3.1.1)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.10.4/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# read Excel file into a Pandas dataframe
df = pd.read_excel('DATA/TestData.xlsx')

# print the dataframe to verify it was imported correctly
df.head(5)
# Out:
#   ELD Seq #  #event record status 1-a,2e  Event record origin  event type  \
# 0        AA                            1                    2           1
# 1         4                            1                    2           1
# 2         3                            1                    2           1
# 3         F                            1                    2           1
# 4         D                            1                    2           1
#
#    event code date(mm/dd/yy) time(h,m,s)  {Accumulated} Vehicle \nMiles  \
# 0           1     2023-03-09    00:00:00                              0
# 1           1     2023-03-09    01:00:00                             88
# 2           4     2023-03-09    02:00:00                             78
# 3           1     2023-03-09    03:00:00                             36
# 4           4     2023-03-09    04:00:00                              0
#
#    Engine Hours  Latitude  Longitude  Distance Since Last Valid Coordinates  \
# 0           0.0   40.7128   -74.0060                                      0
# 1           0.0   41.3012   -72.9293                                      0
# 2           0.0   41.9243   -71.5557                                      0
# 3           0.0   42.3584   -71.0598                                      0
# 4          18.0   42.3601   -71.0589                                      0
#
#    Corresponding CMV} Order \nNumber  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  2
# 4                                  2
#
#    User} Order Number {for Record Originator  \
# 0                                          1
# 1                                          1
# 2                                          1
# 3                                          1
# 4                                          1
#
#    <Malfunction \nIndicator Status {for ELD}  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#    Data Diagnostic Event Indicator Status <Event Data Check Value  \
# 0                                       0                       8
# 1                                       0                      7F
# 2                                       0                      37
# 3                                       0                      B9
# 4                                       0                      C1
#
#   Line \nData Check Value>
# 0                       BD
# 1                       45
# 2                       FD
# 3                       83
# 4                       C2

# %%
#One approach
# create map object with center at the first location in the dataframe
m = folium.Map(location=[df['Latitude'][0], df['Longitude'][0]], zoom_start=10)

# add markers for each location in the dataframe
for index, row in df.iterrows():
    folium.Marker(location=[row['Latitude'], row['Longitude']]).add_to(m)

# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_165896615c85baf64b5c2d2d6162d0fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_165896615c85baf64b5c2d2d6162d0fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_165896615c85baf64b5c2d2d6162d0fb = L.map(
#                 &quot;map_165896615c85baf64b5c2d2d6162d0fb&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfa8f81583f5fd4ef2d8a77d901528c0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_98a744799e0528b31b16b221068443a0 = L.marker(
#                 [40.7128, -74.006],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_315f174ff257ca20fbc68f6506e4ec71 = L.marker(
#                 [41.3012, -72.9293],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_0f17be00ea1a7de3ccc1ca89a75254d4 = L.marker(
#                 [41.9243, -71.5557],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_572e0512a523dad15b8f189fd852401c = L.marker(
#                 [42.3584, -71.0598],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_67d46dfc4b01759b60c0f9658700980c = L.marker(
#                 [42.3601, -71.0589],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_23ac72ff080af1fa74a7b301b942166d = L.marker(
#                 [42.3334, -71.0495],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_19e5a6c40ebe9122a5d0cd98cd264c1d = L.marker(
#                 [42.3645, -71.1024],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_d4e1bba7fd44a9187b594c38fe48e363 = L.marker(
#                 [42.3894, -71.09],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_46f74e833e37df8312dab87025f615ab = L.marker(
#                 [42.3457, -71.0983],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_2741af0729dc2b1a8bb0b501f3604574 = L.marker(
#                 [42.3329, -71.1704],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_f1bb63c38c72078eb7f6e49284552bcd = L.marker(
#                 [42.3337, -71.2112],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_8187e6b87e399796ed852ae0eea2fcaf = L.marker(
#                 [42.3439, -71.1398],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_f546b9ec409f1e7093fb1baa410b34a3 = L.marker(
#                 [42.3662, -71.0621],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_70fee6075dc83e0189421ba161859743 = L.marker(
#                 [42.3712, -71.0202],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_2ab114e2a0d408fb75902ec0de2be3db = L.marker(
#                 [42.3601, -71.0589],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_112406dd3c6587989301e52f12e67b7d = L.marker(
#                 [42.3505, -71.0721],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_5a896d161616b791382a7c37edc7de13 = L.marker(
#                 [42.3584, -71.0598],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_d77da3b9814f9e17aefb6b0facf3edba = L.marker(
#                 [42.3225, -71.2074],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_d1e3aefe5fa5a8275e252b3a525e8dbf = L.marker(
#                 [42.3323, -71.2625],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_ae52525ebd12550146093bcbc4ed0b44 = L.marker(
#                 [42.3407, -71.1163],
#                 {}
#             ).addTo(map_165896615c85baf64b5c2d2d6162d0fb);
#
#
#             var marker_bb86b920ec95196dd212c624e1cb96d6 = L.marker(
#                 [42.3457, -71.0983],
#                 {}
#             ).addTo(map_165

# %% [markdown]
# %pip install gmplot
# import gmplot
# # create a new gmplot object with the center set to the first location in the dataframe
# gmap = gmplot.GoogleMapPlotter(df['Latitude'][0], df['Longitude'][0], 13)
# # add a series of markers to the map to plot the trajectory of the truck
# for index, row in df.iterrows():
#     gmap.marker(row['Latitude'], row['Longitude'])
# # save the map as an HTML file in your workspace
# gmap.draw('map.html')

# %%
# %pip install gmplot
import gmplot
# Out:
# Requirement already satisfied: gmplot in /usr/local/python/3.10.4/lib/python3.10/site-packages (1.4.1)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from gmplot) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->gmplot) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->gmplot) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests->gmplot) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->gmplot) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.
# Bad pipe message: %s [b'\xf0sY\x08?"\xc3T\xc2\xc6\xc9\xc2\x12\xbf\x86O\x1e\xca \xfa\xcb\tJ`p\xaf4~^*q\xa2;\x91\x06\xe8\xef~\xc3r\x98p\xcf\xd1q\xfc\xec\xf6\xeb\x98\xf5\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t1', b'.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04', b'\x03\x06', b'\x07\x08']
# Bad pipe message: %s [b'\t\x08\n\x08\x0b\x08\x04']
# Bad pipe message: %s [b'\xa1I\x9b\xc5\xc3\\\x99#T3\x18\xf2}{i\xbf\xdb\r \xcd\xb1X\xb0\xd7\x7f4\xa7L\xc5\x04(1~qBMB\xb3\x1368\x935%\x81\xbd\xe8\xbf\xe7ZF\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00']
# Bad pipe message: %s [b'\xe5l\xfeP\x1a\xf2"\xbc\x8d\xc6\x9c\xa1\x85\x8f\x06}\xdd\xd5\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0\'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17']
# Bad pipe message: %s [b'[\x871{[\xca\xa2\xb8\xe4\xb7\xdd\x06\xbb1\x85\x86\x11\x11\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s', b"\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06", b'', b'\x03\x03']
# Bad pipe message: %s [b'\x9a\xa16\xbf\x03>Z\xe9\x1c\xfe\x85\x88\xcf\xbf\xf6N}A\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00', b'\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00']
# Bad pipe message: %s [b'\x08\x06\x04\x01\x05\x01\x06', b'']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 3R\x1a\xdb\xb55\x89O\xd6\x01\xd6\xca\xccrK\xa1\x0f\xaf\xf0\xe1=\xcb']
# Bad pipe message: %s [b'', b'\x02']
# Bad pipe message: %s [b'\x05\x02\x06']
# Bad pipe message: %s [b'.,v\xab\xa6h\x8fK,d\r\xd0w\xc0`\xa7j\x04\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x15\x03\x00\x00']
# Bad pipe message: %s [b'(']
# Bad pipe message: %s [b'\x1ePWH\x8b\x0b\xe3+\xbf\x08']
# Bad pipe message: %s [b"\x12\xddy\xd5^\x07:\xfc\xa58\xe8\xd3\xf5\xfb\xb7\xd0\x8f<\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04"]

# %%
# create a new gmplot object with the center set to the first location in the dataframe
gmap = gmplot.GoogleMapPlotter(df['Latitude'][0], df['Longitude'][0], 13)
# add a series of markers to the map to plot the trajectory of the truck
for index, row in df.iterrows():
    gmap.marker(row['Latitude'], row['Longitude'])
# save the map as an HTML file in your workspace
gmap.draw('map.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # create a new gmplot object with the center set to the first location in the dataframe
# ----> 2 gmap = gmplot.GoogleMapPlotter(df['Latitude'][0], df['Longitude'][0], 13)
#       3 # add a series of markers to the map to plot the trajectory of the truck
#       4 for index, row in df.iterrows():
#
# NameError: name 'gmplot' is not defined

# %% [markdown]
# #[ELD Sequence,	Event record status,	Event record origin,	Event Type,	Event Code,	Date,	Time,	Accumulated Vehicle Miles,	Engine Hours,	Latitude,	Longitude,	Distance Since Last Valid Coordinates,	Corresponding CMV Order
# Number,	Order Number for Record Originator,	Malfunction Indicator Status,	Data Diagnostic Event Indicator Status,	Event Data Check Value,	Line Data Check Value]
